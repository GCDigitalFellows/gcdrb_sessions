# %%
#American time use survey
#http://www.bls.gov/tus/#tables
import pandas as pd

# %%
#american time use survey has multiple sheets, one for each year
atu_path = 'data/a2_all_years.xlsx'
#lets look first at 2013
df = pd.read_excel(atu_path, '2003')

# %%
#lets view first few lines
df.head()
# Out:
#   Table A-2.  Time spent in detailed primary activities 1 and percent of the civilian population engaging in each detailed primary activity category, averages per day by sex on weekdays and weekends, 2003 annual averages  \
# 0                                           Activity
# 1                                                NaN
# 2                                              Total
# 3                              Total, all activities
# 4                                                NaN
#
#                                    Unnamed: 1               Unnamed: 2  \
# 0  Average hours per day, civilian population                      NaN
# 1                                    Weekdays  Weekends and holidays 2
# 2                                         NaN                      NaN
# 3                                          24                       24
# 4                                         NaN                      NaN
#
# ...

# %%
#header parsed badly, so let's fix
#data we want is in lines 4-93, headers are in 1, so
pd.read_excel?

# %%
#row 2 has column titles
pd.read_excel(atu_path,'2003', header=2 ).head()#0
# Out:
#                                                     Weekdays  \
# Total                                                    NaN
# Total, all activities                                  24.00
# NaN                                                      NaN
# Personal care activities                       ...      9.05
#     Sleeping                                   ...      8.26
#
#                                                     Weekends and holidays 2  \
# Total                                                                   NaN
# Total, all activities                                                 24.00
# NaN                                                                     NaN
# Personal care activities                       ...                    10.03
#     Sleeping                                   ...                     9.29
#
#                                                     Weekdays.1  \
# Total                                                      NaN
# ...

# %%
#what happened? 0 based indexing!
df = pd.read_excel(atu_path,'2003', header=1 ) #we'll fix column names later
df.head()
# Out:
#                                             Activity  \
# 0                                                NaN
# 1                                              Total
# 2                              Total, all activities
# 3                                                NaN
# 4  Personal care activities                      ...
#
#   Average hours per day, civilian population               Unnamed: 2  \
# 0                                   Weekdays  Weekends and holidays 2
# 1                                        NaN                      NaN
# 2                                         24                       24
# 3                                        NaN                      NaN
# 4                                       9.05                    10.03
#
#   Average percent engaged in the activity per day               Unnamed: 4  \
# 0                                        Weekdays  Weekends and holidays 2
# ...

# %%
df.shape
df
# Out:
#                                               Activity  \
# 0                                                  NaN
# 1                                                Total
# 2                                Total, all activities
# 3                                                  NaN
# 4    Personal care activities                      ...
# 5        Sleeping                                  ...
# 6        Grooming                                  ...
# 7        Health-related self care                  ...
# 8        Personal activities                       ...
# 9        Travel related to personal care           ...
# 10   Eating and drinking                           ...
# 11       Eating and drinking                       ...
# 12       Travel related to eating and drinking     ...
# 13                                Household activities
# 14                                           Housework
# 15                        Food preparation and cleanup
# ...

# %%
#american time use survey has multiple sheets, one for each year
#lets make a list of sheet names
with pd.ExcelFile('path_to_file.xls') as xls:
    df1 = pd.read_excel(xls, 'Sheet1')
    df2 = pd.read_excel(xls, 'Sheet2')

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
